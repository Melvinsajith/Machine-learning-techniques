# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (0.23.4)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.23.5)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (2.1.1)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.11.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from mlxtend) (3.7.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.42.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (6.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.0->mlxtend) (3.16.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\DELL\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.frequent_patterns import apriori, association_rules
df = pd.read_csv("Groceries_dataset.csv")
df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
# df["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y")
customer_visits = df["Member_number"].value_counts()
high_threshold = customer_visits.quantile(0.90)
low_threshold = customer_visits.quantile(0.10)
frequent_customers = customer_visits[customer_visits >= high_threshold]
infrequent_customers = customer_visits[customer_visits <= low_threshold]
# plt.figure(figsize=(4, 3))
sns.histplot(frequent_customers, bins=20, color="blue", label="Frequent Customers", kde=True)
sns.histplot(infrequent_customers, bins=20, color="red", label="Infrequent Customers", kde=True)
plt.xlabel("Number of Visits")
plt.ylabel("Customer Count")
plt.title("Customers Who Visited More Often vs. Less Often")
plt.legend()
plt.show()

# %%
#Plot Most often bought Groceries and Less often bought Groceries.
grocery_counts = df["itemDescription"].value_counts()

grocery_counts.head(10).plot(kind='bar', color='green', label='Most Often Bought')
grocery_counts.tail(10).plot(kind='bar', color='red', label='Less Often Bought')
plt.xlabel("Groceries")
plt.ylabel("Count")
plt.title("Most and Least Frequently Bought Groceries")
plt.legend()
plt.show()

# %%
df["Day"] = df["Date"].dt.day
daily_counts = df.groupby("Day")["itemDescription"].count()
plt.figure(figsize=(4, 3))
daily_counts.plot(kind='bar', color='purple')
plt.xlabel("Day of the Month")
plt.ylabel("Groceries Bought")
plt.title("Groceries Bought on Each Day of the Month")
# plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(6, 5))
daily_counts.plot(kind='pie', autopct='%1.1f%%', colormap='viridis')
plt.ylabel("")
plt.title("Groceries Count on Each Day")
plt.show()

# %%
basket = df.groupby(['Member_number', 'itemDescription'])['Date'].count().unstack().fillna(0)
basket = basket.applymap(lambda x: 1 if x > 0 else 0)
min_support = 0.01
min_confidence = 0.2
frequent_itemsets = apriori(basket, min_support=min_support, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
rules = rules.sort_values(by='lift', ascending=False)
print("Frequent Itemsets:")
print(frequent_itemsets.head())
print("\nAssociation Rules:")
print(rules.head())
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12276\2941441963.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   basket = basket.applymap(lambda x: 1 if x > 0 else 0)
# C:\Users\DELL\AppData\Local\Programs\Python\Python39\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Frequent Itemsets:
#     support                 itemsets
# 0  0.015393  (Instant food products)
# 1  0.078502               (UHT-milk)
# 2  0.031042          (baking powder)
# 3  0.119548                   (beef)
# 4  0.079785                (berries)
#
# Association Rules:
#                                   antecedents                  consequents  \
# 5820  (whole milk, other vegetables, sausage)         (rolls/buns, yogurt)
# 5814   (other vegetables, rolls/buns, yogurt)        (whole milk, sausage)
# 4902                           (curd, yogurt)        (whole milk, sausage)
# 5818        (whole milk, sausage, rolls/buns)   (other vegetables, yogurt)
# 5813         (whole milk, rolls/buns, yogurt)  (other vegetables, sausage)
#
#       antecedent support  consequent support   support  confidence      lift  \
# 5820            0.050282            0.111339  0.013597    0.270408  2.428689
# 5814            0.052335            0.106978  0.013597    0.259804  2.428575
# 4902            0.040277            0.106978  0.010005    0.248408  2.322046
# 5818            0.048743            0.120318  0.013597    0.278947  2.318415
# 5813            0.065931            0.092868  0.013597    0.206226  2.220629
#
#       representativity  leverage  conviction  zhangs_metric   jaccard  \
# 5820               1.0  0.007998    1.218025       0.619400  0.091854
# 5814               1.0  0.007998    1.206467       0.620721  0.093310
# 4902               1.0  0.005696    1.188173       0.593239  0.072897
# 5818               1.0  0.007732    1.219997       0.597810  0.087459
# 5813               1.0  0.007474    1.142808       0.588476  0.093640
#
#       certainty  kulczynski
# 5820   0.178999    0.196264
# 5814   0.171133    0.193451
# 4902   0.158372    0.170966
# 5818   0.180326    0.195977
# 5813   0.124963    0.176317
