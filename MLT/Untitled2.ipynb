# %%
from ast import Load
import tensorflow as tf
from tensorflow.keras import models,layers
from tensorflow.keras.datasets import fashion_mnist

(x_train,y_train),(x_test,y_test) = fashion_mnist.load_data()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 from ast import Load
#       2 import tensorflow as tf
# ----> 3 from tensorflow.keras import models,layers
#       4 from tensorflow.keras.datasets import fashion_mnist
#       6 (x_train,y_train),(x_test,y_test) = fashion_mnist.load_data()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\_tf_keras\keras\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.api import activations
#       8 from keras.api import applications
#       9 from keras.api import callbacks
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\__init__.py:2
#       1 # DO NOT EDIT. Generated by api_gen.sh
# ----> 2 from keras.api import DTypePolicy
#       3 from keras.api import FloatDTypePolicy
#       4 from keras.api import Function
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\api\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.api import activations
#       9 from keras.api import applications
#      10 from keras.api import backend
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\api\activations\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.activations import deserialize
#       8 from keras.src.activations import get
#       9 from keras.src.activations import serialize
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\__init__.py:1
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\activations\__init__.py:33
#      31 from keras.src.activations.activations import threshold
#      32 from keras.src.api_export import keras_export
# ---> 33 from keras.src.saving import object_registration
#      34 from keras.src.saving import serialization_lib
#      36 ALL_OBJECTS = {
#      37     relu,
#      38     leaky_relu,
#    (...)
#      65     sparsemax,
#      66 }
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\saving\__init__.py:7
#       5 from keras.src.saving.object_registration import get_registered_object
#       6 from keras.src.saving.object_registration import register_keras_serializable
# ----> 7 from keras.src.saving.saving_api import load_model
#       8 from keras.src.saving.serialization_lib import deserialize_keras_object
#       9 from keras.src.saving.serialization_lib import serialize_keras_object
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\saving\saving_api.py:7
#       4 from absl import logging
#       6 from keras.src.api_export import keras_export
# ----> 7 from keras.src.legacy.saving import legacy_h5_format
#       8 from keras.src.saving import saving_lib
#       9 from keras.src.utils import file_utils
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:13
#      11 from keras.src.legacy.saving import json_utils
#      12 from keras.src.legacy.saving import saving_options
# ---> 13 from keras.src.legacy.saving import saving_utils
#      14 from keras.src.saving import object_registration
#      15 from keras.src.utils import io_utils
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\legacy\saving\saving_utils.py:10
#       8 from keras.src import losses
#       9 from keras.src import metrics as metrics_module
# ---> 10 from keras.src import models
#      11 from keras.src import optimizers
#      12 from keras.src import tree
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\models\__init__.py:1
# ----> 1 from keras.src.models.functional import Functional
#       2 from keras.src.models.model import Model
#       3 from keras.src.models.sequential import Sequential
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\models\functional.py:16
#      14 from keras.src.legacy.saving import saving_utils
#      15 from keras.src.legacy.saving import serialization as legacy_serialization
# ---> 16 from keras.src.models.model import Model
#      17 from keras.src.ops.function import Function
#      18 from keras.src.ops.function import _build_map
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\models\model.py:12
#      10 from keras.src.models.variable_mapping import map_saveable_variables
#      11 from keras.src.saving import saving_api
# ---> 12 from keras.src.trainers import trainer as base_trainer
#      13 from keras.src.utils import summary_utils
#      14 from keras.src.utils import traceback_utils
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\trainers\trainer.py:14
#      12 from keras.src.trainers.compile_utils import CompileLoss
#      13 from keras.src.trainers.compile_utils import CompileMetrics
# ---> 14 from keras.src.trainers.data_adapters import data_adapter_utils
#      15 from keras.src.utils import python_utils
#      16 from keras.src.utils import traceback_utils
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\trainers\data_adapters\__init__.py:4
#       1 import types
#       3 from keras.src.distribution import distribution_lib
# ----> 4 from keras.src.trainers.data_adapters import array_data_adapter
#       5 from keras.src.trainers.data_adapters import data_adapter
#       6 from keras.src.trainers.data_adapters import py_dataset_adapter
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:7
#       4 import numpy as np
#       6 from keras.src import tree
# ----> 7 from keras.src.trainers.data_adapters import array_slicing
#       8 from keras.src.trainers.data_adapters import data_adapter_utils
#       9 from keras.src.trainers.data_adapters.data_adapter import DataAdapter
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\trainers\data_adapters\array_slicing.py:12
#       9 from keras.src.utils.module_utils import tensorflow as tf
#      11 try:
# ---> 12     import pandas
#      13 except ImportError:
#      14     pandas = None
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\__init__.py:73
#      70 # let init-time option registration happen
#      71 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 73 from pandas.core.api import (
#      74     # dtype
#      75     ArrowDtype,
#      76     Int8Dtype,
#      77     Int16Dtype,
#      78     Int32Dtype,
#      79     Int64Dtype,
#      80     UInt8Dtype,
#      81     UInt16Dtype,
#      82     UInt32Dtype,
#      83     UInt64Dtype,
#      84     Float32Dtype,
#      85     Float64Dtype,
#      86     CategoricalDtype,
#      87     PeriodDtype,
#      88     IntervalDtype,
#      89     DatetimeTZDtype,
#      90     StringDtype,
#      91     BooleanDtype,
#      92     # missing
#      93     NA,
#      94     isna,
#      95     isnull,
#      96     notna,
#      97     notnull,
#      98     # indexes
#      99     Index,
#     100     CategoricalIndex,
#     101     RangeIndex,
#     102     MultiIndex,
#     103     IntervalIndex,
#     104     TimedeltaIndex,
#     105     DatetimeIndex,
#     106     PeriodIndex,
#     107     IndexSlice,
#     108     # tseries
#     109     NaT,
#     110     Period,
#     111     period_range,
#     112     Timedelta,
#     113     timedelta_range,
#     114     Timestamp,
#     115     date_range,
#     116     bdate_range,
#     117     Interval,
#     118     interval_range,
#     119     DateOffset,
#     120     # conversion
#     121     to_numeric,
#     122     to_datetime,
#     123     to_timedelta,
#     124     # misc
#     125     Flags,
#     126     Grouper,
#     127     factorize,
#     128     unique,
#     129     value_counts,
#     130     NamedAgg,
#     131     array,
#     132     Categorical,
#     133     set_eng_float_format,
#     134     Series,
#     135     DataFrame,
#     136 )
#     138 from pandas.core.dtypes.dtypes import SparseDtype
#     140 from pandas.tseries.api import infer_freq
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\api.py:1
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
#       9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#    (...)
#      14     PeriodDtype,
#      15 )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\__init__.py:18
#      16 import pandas._libs.pandas_parser  # noqa: E501 # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401,E501 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)
#      26     iNaT,
#      27 )
#
# File interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
